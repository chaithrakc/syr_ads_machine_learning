# %%
# importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### 1. Loading data

# %%
df = pd.read_csv('bankdata_csv_all.csv')

# %%
df.head()
# Out:
#         id  age     sex      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# 2         YES       NO   NO
# 3         YES       NO   NO
# 4          NO       NO   NO

# %%
df.shape
# Out:
# (600, 12)

# %% [markdown]
# #### 2. Data Pre-Processing

# %%
df.isnull().sum() # no null values
# Out:
# id             0
# age            0
# sex            0
# region         0
# income         0
# married        0
# children       0
# car            0
# save_act       0
# current_act    0
# mortgage       0
# pep            0
# dtype: int64

# %%
df.isna().sum() # no NA values
# Out:
# id             0
# age            0
# sex            0
# region         0
# income         0
# married        0
# children       0
# car            0
# save_act       0
# current_act    0
# mortgage       0
# pep            0
# dtype: int64

# %%
# removing the id field
df.drop('id',axis=1, inplace=True)

# %%
# summary of the statistical data
df.describe().transpose()
# Out:
#           count          mean           std      min      25%      50%  \
# age       600.0     42.395000     14.424947    18.00     30.0     42.0
# income    600.0  27524.031217  12899.468246  5014.21  17264.5  24925.3
# children  600.0      1.011667      1.056752     0.00      0.0      1.0
#
#                 75%      max
# age          55.250     67.0
# income    36172.675  63130.1
# children      2.000      3.0

# %%
# Discretizing age column - converting numeric value to categorical value
df['age_group']=pd.cut(df['age'],bins=[0,10,20,30,40,50,60,100], 
                      labels=["child","teens","twenties","thirties","fourties","fifties","old"])

# %%
df.head()
# Out:
#    age     sex      region   income married  children  car save_act  \
# 0   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep age_group  gender_dummy  married_dummy  car_dummy  \
# 0          NO       NO  YES  fourties             0              0          0
# 1         YES      YES   NO  thirties             1              1          1
# 2         YES       NO   NO   fifties             0              1          1
# 3         YES       NO   NO  twenties             0              1          0
# 4          NO       NO   NO   fifties             0              1          0
#
#    savingsaccnt_dummy  currentaccnt_dummy  mortgage_dummy  pep_dummy
# 0                   0                   0               0          1
# 1                   0                   1               1          0
# 2                   1                   1               0          0
# 3                   0                   1               0          0
# 4                   1                   0               0          0

# %%
# discretizing sex,married,car,save_act,current_act,mortgage,pep columns by label encoding
le = LabelEncoder()
df['gender_dummy'] = le.fit_transform(df['sex']) # female - 0 , male-1
df['married_dummy'] = le.fit_transform(df['married']) # No - 0, Yes - 1
df['car_dummy'] = le.fit_transform(df['car'])
df['savingsaccnt_dummy'] = le.fit_transform(df['save_act'])
df['currentaccnt_dummy'] = le.fit_transform(df['current_act'])
df['mortgage_dummy'] = le.fit_transform(df['mortgage'])
df['pep_dummy'] = le.fit_transform(df['pep'])

# %%
df.head()
# Out:
#    age     sex      region   income married  children  car save_act  \
# 0   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep age_group  gender_dummy  married_dummy  car_dummy  \
# 0          NO       NO  YES  fourties             0              0          0
# 1         YES      YES   NO  thirties             1              1          1
# 2         YES       NO   NO   fifties             0              1          1
# 3         YES       NO   NO  twenties             0              1          0
# 4          NO       NO   NO   fifties             0              1          0
#
#    savingsaccnt_dummy  currentaccnt_dummy  mortgage_dummy  pep_dummy
# 0                   0                   0               0          1
# 1                   0                   1               1          0
# 2                   1                   1               0          0
# 3                   0                   1               0          0
# 4                   1                   0               0          0

# %%
bankdata_oneHot = pd.get_dummies(df)

# %%
bankdata_oneHot
# Out:
#      age    income  children  sex_FEMALE  sex_MALE  region_INNER_CITY  \
# 0     48  17546.00         1           1         0                  1
# 1     40  30085.10         3           0         1                  0
# 2     51  16575.40         0           1         0                  1
# 3     23  20375.40         3           1         0                  0
# 4     57  50576.30         0           1         0                  0
# ..   ...       ...       ...         ...       ...                ...
# 595   61  47025.00         2           1         0                  1
# 596   30   9672.25         0           1         0                  1
# 597   31  15976.30         0           1         0                  0
# 598   29  14711.80         0           0         1                  1
# 599   38  26671.60         0           0         1                  0
#
#      region_RURAL  region_SUBURBAN  region_TOWN  married_NO  ...  car_NO  \
# 0               0                0            0           1  ...       1
# 1               0                0            1           0  ...       0
# 2               0                0            0           0  ...       0
# 3               0                0            1           0  ...       1
# 4               1                0            0           0  ...       1
# ..            ...              ...          ...         ...  ...     ...
# 595             0                0            0           1  ...       0
# 596             0                0            0           0  ...       0
# 597             0                0            1           0  ...       0
# 598             0                0            0           0  ...       1
# 599             0                0            1           1  ...       0
#
#      car_YES  save_act_NO  save_act_YES  current_act_NO  current_act_YES  \
# 0          0            1             0               1                0
# 1          1            1             0               0                1
# 2          1            0             1               0                1
# 3          0            1             0               0                1
# 4          0            0             1               1                0
# ..       ...          ...           ...             ...              ...
# 595        1            0             1               0                1
# 596        1            0             1               0                1
# 597        1            0             1               1                0
# 598        0            0             1               1                0
# 599        1            1             0               0                1
#
#      mortgage_NO  mortgage_YES  pep_NO  pep_YES
# 0              1             0       0        1
# 1              0             1       1        0
# 2              1             0       1        0
# 3              1             0       1        0
# 4              1             0       1        0
# ..           ...           ...     ...      ...
# 595            0             1       1        0
# 596            1             0       1        0
# 597            1             0       0        1
# 598            0             1       1        0
# 599            0             1       0        1
#
# [600 rows x 21 columns]

# %% [markdown]
# #### 3. Association Rule Mining

# %%
records = []
for i in range(df.shape[0]):
    records.append([str(df.values[i,j]) for j in range(df.shape[1])])

# %%
association_rules = apriori(records, min_support=0.009, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21568/507182413.py in <module>
#       1 association_rules = apriori(records, min_support=0.009, min_confidence=0.2, min_lift=3, min_length=2)
# ----> 2 association_results = list(association_rules)
#
# ~\anaconda3\lib\site-packages\apyori.py in apriori(transactions, **kwargs)
#     284
#     285     # Calculate ordered stats.
# --> 286     for support_record in support_records:
#     287         ordered_statistics = list(
#     288             _filter_ordered_statistics(
#
# ~\anaconda3\lib\site-packages\apyori.py in gen_support_records(transaction_manager, min_support, **kwargs)
#     197         if max_length and length > max_length:
#     198             break
# --> 199         candidates = _create_next_candidates(relations, length)
#     200
#     201
#
# ~\anaconda3\lib\site-packages\apyori.py in create_next_candidates(prev_candidates, length)
#     155     # Filter candidates that all of their subsets are
#     156     # in the previous candidates.
# --> 157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
#     159         if all(
#
# ~\anaconda3\lib\site-packages\apyori.py in <listcomp>(.0)
#     157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
# --> 159         if all(
#     160             frozenset(x) in prev_candidates
#     161             for x in combinations(candidate, length - 1))
#
# ~\anaconda3\lib\site-packages\apyori.py in <genexpr>(.0)
#     157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
# --> 159         if all(
#     160             frozenset(x) in prev_candidates
#     161             for x in combinations(candidate, length - 1))
#
# KeyboardInterrupt:

# %%
association_results
# Out:
# []

# %% [markdown]
# Reference:
# https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python/
